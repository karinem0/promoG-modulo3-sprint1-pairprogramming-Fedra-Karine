# %%
import numpy as pd 
import pandas as pd
# Out:
# C:\Users\karin\AppData\Local\Temp\ipykernel_12376\2029176699.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # PAIR PROGRAMMING EDA
#
# ## Ejercicios de exploración del conjunto de datos
#
# 1. Muestra las primeras 5 filas del conjunto de datos.

# %%
#   Abrimos el csv especificando la ruta
df_world = pd.read_csv('world-data-2023_part1.csv')
df_world
# Out:
#      Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0             0  Afghanistan               60           AF
# 1             1      Albania              105           AL
# 2             2      Algeria               18           DZ
# 3             3      Andorra              164           AD
# 4             4       Angola               26           AO
# ..          ...          ...              ...          ...
# 190         190    Venezuela               32           VE
# 191         191      Vietnam              314           VN
# 192         192        Yemen               56           YE
# 193         193       Zambia               25           ZM
# 194         194     Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 0                  58.10%        652,230           323,000       32.49
# 1                  43.10%         28,748             9,000       11.78
# 2                  17.40%      2,381,741           317,000       24.28
# 3                  40.00%            468               NaN        7.20
# 4                  47.50%      1,246,700           117,000       40.73
# ..                    ...            ...               ...         ...
# 190                24.50%        912,050           343,000       17.88
# 191                39.30%        331,210           522,000       16.75
# 192                44.60%        527,968            40,000       30.45
# 193                32.10%        752,618            16,000       36.19
# 194                41.90%        390,757            51,000       30.68
#
#      Calling Code Capital/Major City Co2-Emissions       CPI CPI Change (%)  \
# 0            93.0              Kabul         8,672     149.9          2.30%
# 1           355.0             Tirana         4,536    119.05          1.40%
# 2           213.0            Algiers       150,006    151.36          2.00%
# 3           376.0   Andorra la Vella           469       NaN            NaN
# 4           244.0             Luanda        34,693    261.73         17.10%
# ..            ...                ...           ...       ...            ...
# 190          58.0            Caracas       164,175  2,740.27        254.90%
# 191          84.0              Hanoi       192,668    163.52          2.80%
# 192         967.0              Sanaa        10,609    157.58          8.10%
# 193         260.0             Lusaka         5,141    212.31          9.20%
# 194         263.0             Harare        10,983    105.51          0.90%
#
#     Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 0             AFN            4.47             2.10%         $0.70
# 1             ALL            1.62            28.10%         $1.36
# 2             DZD            3.02             0.80%         $0.28
# 3             EUR            1.27            34.00%         $1.51
# 4             AOA            5.52            46.30%         $0.97
# ..            ...             ...               ...            ...
# 190           VED            2.27            52.70%         $0.00
# 191           VND            2.05            48.10%         $0.80
# 192           YER            3.79             1.00%         $0.92
# 193           ZMW            4.63            65.20%         $1.40
# 194           NaN            3.62            35.50%         $1.34
#
# [195 rows x 17 columns]

# %%
# Sacamos las 5 primeras filas del Df
df_world.head(5)
# Out:
#    Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0           0  Afghanistan               60           AF
# 1           1      Albania              105           AL
# 2           2      Algeria               18           DZ
# 3           3      Andorra              164           AD
# 4           4       Angola               26           AO
#
#   Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 0                58.10%        652,230           323,000       32.49
# 1                43.10%         28,748             9,000       11.78
# 2                17.40%      2,381,741           317,000       24.28
# 3                40.00%            468               NaN        7.20
# 4                47.50%      1,246,700           117,000       40.73
#
#    Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 0          93.0              Kabul         8,672   149.9          2.30%
# 1         355.0             Tirana         4,536  119.05          1.40%
# 2         213.0            Algiers       150,006  151.36          2.00%
# 3         376.0   Andorra la Vella           469     NaN            NaN
# 4         244.0             Luanda        34,693  261.73         17.10%
#
#   Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 0           AFN            4.47             2.10%         $0.70
# 1           ALL            1.62            28.10%         $1.36
# 2           DZD            3.02             0.80%         $0.28
# 3           EUR            1.27            34.00%         $1.51
# 4           AOA            5.52            46.30%         $0.97

# %% [markdown]
# 2. Muestra las últimas 5 filas del conjunto de datos.

# %%
# Sacamos las últimas 5 filas
df_world.tail(5)
# Out:
#      Unnamed: 0    Country Density\n(P/Km2) Abbreviation  \
# 190         190  Venezuela               32           VE
# 191         191    Vietnam              314           VN
# 192         192      Yemen               56           YE
# 193         193     Zambia               25           ZM
# 194         194   Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 190                24.50%        912,050           343,000       17.88
# 191                39.30%        331,210           522,000       16.75
# 192                44.60%        527,968            40,000       30.45
# 193                32.10%        752,618            16,000       36.19
# 194                41.90%        390,757            51,000       30.68
#
#      Calling Code Capital/Major City Co2-Emissions       CPI CPI Change (%)  \
# 190          58.0            Caracas       164,175  2,740.27        254.90%
# 191          84.0              Hanoi       192,668    163.52          2.80%
# 192         967.0              Sanaa        10,609    157.58          8.10%
# 193         260.0             Lusaka         5,141    212.31          9.20%
# 194         263.0             Harare        10,983    105.51          0.90%
#
#     Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 190           VED            2.27            52.70%         $0.00
# 191           VND            2.05            48.10%         $0.80
# 192           YER            3.79             1.00%         $0.92
# 193           ZMW            4.63            65.20%         $1.40
# 194           NaN            3.62            35.50%         $1.34

# %% [markdown]
# 3. Muestra una muestra aleatoria de 5 filas del conjunto de datos.

# %%
# Sacamos 5 filas aleatorias 
df_world.sample(5)
# Out:
#      Unnamed: 0     Country Density\n(P/Km2) Abbreviation  \
# 154         154  Seychelles              214           SC
# 97           97       Libya                4           LY
# 112         112     Moldova              123           MD
# 22           22    Botswana                4           BW
# 57           57    Ethiopia              115           ET
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 154                 3.40%            455                 0       17.10
# 97                  8.70%      1,759,540                 0       18.83
# 112                74.20%         33,851             7,000       10.10
# 22                 45.60%        581,730             9,000       24.82
# 57                 36.30%      1,104,300           138,000       32.34
#
#      Calling Code    Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 154         248.0  Victoria, Seychelles           605  129.96          1.80%
# 97          218.0                   NaN        50,564  125.71          2.60%
# 112         373.0               Chi����         5,115   166.2          4.80%
# 22          267.0              Gaborone         6,340  149.75          2.80%
# 57          251.0           Addis Ababa        14,870  143.86         15.80%
#
#     Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 154           SCR            2.41            88.40%            NaN
# 97            LYD            2.24             0.10%         $0.11
# 112           MDL            1.26            12.60%         $0.80
# 22            BWP            2.87            18.90%         $0.71
# 57            ETB            4.25            12.50%         $0.75

# %% [markdown]
# 4. Muestra el número total de filas y columnas en el conjunto de datos.

# %%
# Devuelve número de filas y columnas 
df_world.shape
# Out:
# (195, 17)

# %% [markdown]
# 5. Muestra el nombre de todas las columnas en el conjunto de datos.

# %%
# Nos devuelve el nombre de todas las columnas 
df_world.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Density\n(P/Km2)', 'Abbreviation',
#        'Agricultural Land( %)', 'Land Area(Km2)', 'Armed Forces size',
#        'Birth Rate', 'Calling Code', 'Capital/Major City', 'Co2-Emissions',
#        'CPI', 'CPI Change (%)', 'Currency-Code', 'Fertility Rate',
#        'Forested Area (%)', 'Gasoline Price'],
#       dtype='object')

# %% [markdown]
# 6. Muestra los valores únicos en la columna "Abbreviation".

# %%
# Sacamos valores unicos de una columna especifica
df_world['Abbreviation'].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'CI', 'CV', 'KH', 'CM', 'CA',
#        'CF', 'TD', 'CL', 'CN', 'CO', 'KM', nan, 'CR', 'HR', 'CU', 'CY',
#        'CZ', 'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER',
#        'EE', 'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR',
#        'GD', 'GT', 'GN', 'GW', 'GY', 'HT', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KI', 'KW',
#        'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI', 'LT', 'LU', 'MG',
#        'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MR', 'MU', 'MX', 'FM', 'MD',
#        'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NR', 'NP', 'NL', 'NZ', 'NI',
#        'NE', 'NG', 'KP', 'NO', 'OM', 'PK', 'PW', 'PA', 'PG', 'PY', 'PE',
#        'PH', 'PL', 'PT', 'QA', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'WS',
#        'SM', 'ST', 'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SB',
#        'SO', 'ZA', 'KR', 'SS', 'ES', 'LK', 'SD', 'SR', 'SE', 'CH', 'SY',
#        'TJ', 'TZ', 'TH', 'TL', 'TG', 'TO', 'TT', 'TN', 'TR', 'TM', 'TV',
#        'UG', 'UA', 'AE', 'GB', 'US', 'UY', 'UZ', 'VU', 'VE', 'VN', 'YE',
#        'ZM', 'ZW'], dtype=object)

# %% [markdown]
# 7. Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation".

# %%
# Nos devuelve cuantas veces aparece cada valor en la columna
df_world['Abbreviation'].value_counts()
# Out:
# Abbreviation
# AF    1
# PY    1
# NE    1
# NG    1
# KP    1
#      ..
# GR    1
# GD    1
# GT    1
# GN    1
# ZW    1
# Name: count, Length: 188, dtype: int64

# %% [markdown]
# 8. Verifica si hay valores nulos en el conjunto de datos.

# %%
# Nos devuelve valores nulos
df_world.isnull()
# Out:
#      Unnamed: 0  Country  Density\n(P/Km2)  Abbreviation  \
# 0         False    False             False         False
# 1         False    False             False         False
# 2         False    False             False         False
# 3         False    False             False         False
# 4         False    False             False         False
# ..          ...      ...               ...           ...
# 190       False    False             False         False
# 191       False    False             False         False
# 192       False    False             False         False
# 193       False    False             False         False
# 194       False    False             False         False
#
#      Agricultural Land( %)  Land Area(Km2)  Armed Forces size  Birth Rate  \
# 0                    False           False              False       False
# 1                    False           False              False       False
# 2                    False           False              False       False
# 3                    False           False               True       False
# 4                    False           False              False       False
# ..                     ...             ...                ...         ...
# 190                  False           False              False       False
# 191                  False           False              False       False
# 192                  False           False              False       False
# 193                  False           False              False       False
# 194                  False           False              False       False
#
#      Calling Code  Capital/Major City  Co2-Emissions    CPI  CPI Change (%)  \
# 0           False               False          False  False           False
# 1           False               False          False  False           False
# 2           False               False          False  False           False
# 3           False               False          False   True            True
# 4           False               False          False  False           False
# ..            ...                 ...            ...    ...             ...
# 190         False               False          False  False           False
# 191         False               False          False  False           False
# 192         False               False          False  False           False
# 193         False               False          False  False           False
# 194         False               False          False  False           False
#
#      Currency-Code  Fertility Rate  Forested Area (%)  Gasoline Price
# 0            False           False              False           False
# 1            False           False              False           False
# 2            False           False              False           False
# 3            False           False              False           False
# 4            False           False              False           False
# ..             ...             ...                ...             ...
# 190          False           False              False           False
# 191          False           False              False           False
# 192          False           False              False           False
# 193          False           False              False           False
# 194           True           False              False           False
#
# [195 rows x 17 columns]

# %% [markdown]
# 9. Verifica si hay valores no nulos en el conjunto de datos.

# %%
# Nos devuelve los valores no nulos
df_world.notnull()
# Out:
#      Unnamed: 0  Country  Density\n(P/Km2)  Abbreviation  \
# 0          True     True              True          True
# 1          True     True              True          True
# 2          True     True              True          True
# 3          True     True              True          True
# 4          True     True              True          True
# ..          ...      ...               ...           ...
# 190        True     True              True          True
# 191        True     True              True          True
# 192        True     True              True          True
# 193        True     True              True          True
# 194        True     True              True          True
#
#      Agricultural Land( %)  Land Area(Km2)  Armed Forces size  Birth Rate  \
# 0                     True            True               True        True
# 1                     True            True               True        True
# 2                     True            True               True        True
# 3                     True            True              False        True
# 4                     True            True               True        True
# ..                     ...             ...                ...         ...
# 190                   True            True               True        True
# 191                   True            True               True        True
# 192                   True            True               True        True
# 193                   True            True               True        True
# 194                   True            True               True        True
#
#      Calling Code  Capital/Major City  Co2-Emissions    CPI  CPI Change (%)  \
# 0            True                True           True   True            True
# 1            True                True           True   True            True
# 2            True                True           True   True            True
# 3            True                True           True  False           False
# 4            True                True           True   True            True
# ..            ...                 ...            ...    ...             ...
# 190          True                True           True   True            True
# 191          True                True           True   True            True
# 192          True                True           True   True            True
# 193          True                True           True   True            True
# 194          True                True           True   True            True
#
#      Currency-Code  Fertility Rate  Forested Area (%)  Gasoline Price
# 0             True            True               True            True
# 1             True            True               True            True
# 2             True            True               True            True
# 3             True            True               True            True
# 4             True            True               True            True
# ..             ...             ...                ...             ...
# 190           True            True               True            True
# 191           True            True               True            True
# 192           True            True               True            True
# 193           True            True               True            True
# 194          False            True               True            True
#
# [195 rows x 17 columns]

# %% [markdown]
# 10. Muestra información general sobre el conjunto de datos.

# %%
# Nos devuelve la informacion general del dataframe 
df_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             195 non-null    int64
#  1   Country                195 non-null    object
#  2   Density
# (P/Km2)        195 non-null    object
#  3   Abbreviation           188 non-null    object
#  4   Agricultural Land( %)  188 non-null    object
#  5   Land Area(Km2)         194 non-null    object
#  6   Armed Forces size      171 non-null    object
#  7   Birth Rate             189 non-null    float64
#  8   Calling Code           194 non-null    float64
#  9   Capital/Major City     192 non-null    object
#  10  Co2-Emissions          188 non-null    object
#  11  CPI                    178 non-null    object
#  12  CPI Change (%)         179 non-null    object
#  13  Currency-Code          180 non-null    object
#  14  Fertility Rate         188 non-null    float64
#  15  Forested Area (%)      188 non-null    object
#  16  Gasoline Price         175 non-null    object
# dtypes: float64(3), int64(1), object(13)
# memory usage: 26.0+ KB

# %% [markdown]
# 11. Elimina una columna específica (por ejemplo, "Armed Forces size").

# %%
# Eliminamos columna concreta

df_world.drop(columns= ["Armed Forces size"], inplace=True)
# Columna ya eliminada, nos da error al ejecutar porque no la encuentra

# %%
# Vemos en el df que se ha eliminado la columna
df_world
# Out:
#      Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0             0  Afghanistan               60           AF
# 1             1      Albania              105           AL
# 2             2      Algeria               18           DZ
# 3             3      Andorra              164           AD
# 4             4       Angola               26           AO
# ..          ...          ...              ...          ...
# 190         190    Venezuela               32           VE
# 191         191      Vietnam              314           VN
# 192         192        Yemen               56           YE
# 193         193       Zambia               25           ZM
# 194         194     Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                  58.10%        652,230       32.49          93.0
# 1                  43.10%         28,748       11.78         355.0
# 2                  17.40%      2,381,741       24.28         213.0
# 3                  40.00%            468        7.20         376.0
# 4                  47.50%      1,246,700       40.73         244.0
# ..                    ...            ...         ...           ...
# 190                24.50%        912,050       17.88          58.0
# 191                39.30%        331,210       16.75          84.0
# 192                44.60%        527,968       30.45         967.0
# 193                32.10%        752,618       36.19         260.0
# 194                41.90%        390,757       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 1               Tirana         4,536    119.05          1.40%           ALL
# 2              Algiers       150,006    151.36          2.00%           DZD
# 3     Andorra la Vella           469       NaN            NaN           EUR
# 4               Luanda        34,693    261.73         17.10%           AOA
# ..                 ...           ...       ...            ...           ...
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 0              4.47             2.10%         $0.70
# 1              1.62            28.10%         $1.36
# 2              3.02             0.80%         $0.28
# 3              1.27            34.00%         $1.51
# 4              5.52            46.30%         $0.97
# ..              ...               ...            ...
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34
#
# [195 rows x 16 columns]

# %% [markdown]
# 12. Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas (para esto tendréis que usar el método '.describe(), su documentación la tenéis aquí).

# %%
# Nos devuelve con describe sin definir nada en el paréntesis por defecto las estádisticas de las variables numéricas: 
# Usando .T nos coloca en la parte superior las variables (ordenadas), traspone el orden 
df_world.describe().T
# Out:
#                 count        mean         std   min     25%      50%  \
# Unnamed: 0      195.0   97.000000   56.435804  0.00  48.500   97.000
# Birth Rate      189.0   20.214974    9.945774  5.90  11.300   17.950
# Calling Code    194.0  360.546392  323.236419  1.00  82.500  255.500
# Fertility Rate  188.0    2.698138    1.282267  0.98   1.705    2.245
#
#                      75%      max
# Unnamed: 0      145.5000   194.00
# Birth Rate       28.7500    46.08
# Calling Code    506.7500  1876.00
# Fertility Rate    3.5975     6.91

# %% [markdown]
# ## Ejercicios con loc e iloc
#
# 1. Selecciona todas las columnas de las filas 2 a 4 (inclusive) utilizando loc.

# %%
df_world
# Out:
#      Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0             0  Afghanistan               60           AF
# 1             1      Albania              105           AL
# 2             2      Algeria               18           DZ
# 3             3      Andorra              164           AD
# 4             4       Angola               26           AO
# ..          ...          ...              ...          ...
# 190         190    Venezuela               32           VE
# 191         191      Vietnam              314           VN
# 192         192        Yemen               56           YE
# 193         193       Zambia               25           ZM
# 194         194     Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                  58.10%        652,230       32.49          93.0
# 1                  43.10%         28,748       11.78         355.0
# 2                  17.40%      2,381,741       24.28         213.0
# 3                  40.00%            468        7.20         376.0
# 4                  47.50%      1,246,700       40.73         244.0
# ..                    ...            ...         ...           ...
# 190                24.50%        912,050       17.88          58.0
# 191                39.30%        331,210       16.75          84.0
# 192                44.60%        527,968       30.45         967.0
# 193                32.10%        752,618       36.19         260.0
# 194                41.90%        390,757       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 1               Tirana         4,536    119.05          1.40%           ALL
# 2              Algiers       150,006    151.36          2.00%           DZD
# 3     Andorra la Vella           469       NaN            NaN           EUR
# 4               Luanda        34,693    261.73         17.10%           AOA
# ..                 ...           ...       ...            ...           ...
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 0              4.47             2.10%         $0.70
# 1              1.62            28.10%         $1.36
# 2              3.02             0.80%         $0.28
# 3              1.27            34.00%         $1.51
# 4              5.52            46.30%         $0.97
# ..              ...               ...            ...
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34
#
# [195 rows x 16 columns]

# %%
# Utilizamos LOC y usamos las ETIQUETAS que son 2 y 4 para las filas 2:4 
df_world.loc[2:4, :]
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 2           2  Algeria               18           DZ                17.40%
# 3           3  Andorra              164           AD                40.00%
# 4           4   Angola               26           AO                47.50%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 2      2,381,741       24.28         213.0            Algiers       150,006
# 3            468        7.20         376.0   Andorra la Vella           469
# 4      1,246,700       40.73         244.0             Luanda        34,693
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 2  151.36          2.00%           DZD            3.02             0.80%
# 3     NaN            NaN           EUR            1.27            34.00%
# 4  261.73         17.10%           AOA            5.52            46.30%
#
#   Gasoline Price
# 2         $0.28
# 3         $1.51
# 4         $0.97

# %%
# Con ILOC usamos la posicion de los INDICES, por eso es de 2:5 (para que incluya posicion 4)
df_world.iloc[2:5, :]
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 2           2  Algeria               18           DZ                17.40%
# 3           3  Andorra              164           AD                40.00%
# 4           4   Angola               26           AO                47.50%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 2      2,381,741       24.28         213.0            Algiers       150,006
# 3            468        7.20         376.0   Andorra la Vella           469
# 4      1,246,700       40.73         244.0             Luanda        34,693
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 2  151.36          2.00%           DZD            3.02             0.80%
# 3     NaN            NaN           EUR            1.27            34.00%
# 4  261.73         17.10%           AOA            5.52            46.30%
#
#   Gasoline Price
# 2         $0.28
# 3         $1.51
# 4         $0.97

# %% [markdown]
# 2. Utilizando loc, filtra el conjunto de datos para mostrar solo las filas donde la densidad (columna "Birth Rate") es mayor a 30.

# %%
# Nos sacará todas las filas y columnas que cumplan la condición. Si quiséramos que nos saque una columna concreta debemos especificar al final la columna[]
df_world.loc[(df_world["Birth Rate"] > 30), 'Birth Rate']
# Out:
# 0      32.49
# 4      40.73
# 18     36.22
# 26     37.93
# 27     39.01
# 28     35.74
# 31     35.39
# 33     35.35
# 34     42.17
# 38     31.88
# 39     32.86
# 45     41.18
# 53     33.24
# 54     30.30
# 57     32.34
# 61     31.61
# 62     38.54
# 69     36.36
# 70     35.13
# 96     33.04
# 101    32.66
# 102    34.12
# 105    41.54
# 108    33.69
# 117    37.52
# 125    46.08
# 126    37.91
# 144    31.70
# 150    31.54
# 152    34.52
# 155    33.41
# 159    32.44
# 160    41.75
# 163    35.01
# 166    32.18
# 171    30.76
# 172    36.70
# 175    33.11
# 182    38.14
# 192    30.45
# 193    36.19
# 194    30.68
# Name: Birth Rate, dtype: float64

# %% [markdown]
# 3. Utilizando loc selecciona las columnas "Country" y "Capital/Major City" de las filas donde el porcentaje de tierra agrícola (columna "Fertility Rate") es superior al 3.

# %%
# Para sacar más de una columna debemos ponerlo entre paréntesis y separado por comas. 
df_world.loc[(df_world["Fertility Rate"] > 3), ('Country','Capital/Major City')]
# Out:
#                               Country Capital/Major City
# 0                         Afghanistan              Kabul
# 2                             Algeria            Algiers
# 4                              Angola             Luanda
# 18                              Benin         Porto-Novo
# 26                       Burkina Faso        Ouagadougou
# 27                            Burundi          Bujumbura
# 28                        Ivory Coast       Yamoussoukro
# 31                           Cameroon            Yaound�
# 33           Central African Republic             Bangui
# 34                               Chad          N'Djamena
# 38                            Comoros    Moroni, Comoros
# 39              Republic of the Congo        Brazzaville
# 45   Democratic Republic of the Congo           Kinshasa
# 51                              Egypt              Cairo
# 53                  Equatorial Guinea             Malabo
# 54                            Eritrea             Asmara
# 57                           Ethiopia        Addis Ababa
# 61                              Gabon         Libreville
# 62                         The Gambia             Banjul
# 65                              Ghana              Accra
# 69                             Guinea            Conakry
# 70                      Guinea-Bissau             Bissau
# 80                               Iraq            Baghdad
# 82                             Israel          Jerusalem
# 88                              Kenya            Nairobi
# 89                           Kiribati       South Tarawa
# 91                         Kyrgyzstan            Bishkek
# 95                            Lesotho             Maseru
# 96                            Liberia           Monrovia
# 101                        Madagascar       Antananarivo
# 102                            Malawi           Lilongwe
# 105                              Mali             Bamako
# 107                  Marshall Islands             Majuro
# 108                        Mauritania         Nouakchott
# 111    Federated States of Micronesia            Palikir
# 117                        Mozambique             Maputo
# 119                           Namibia           Windhoek
# 125                             Niger             Niamey
# 126                           Nigeria              Abuja
# 131                          Pakistan          Islamabad
# 135                  Papua New Guinea       Port Moresby
# 144                            Rwanda             Kigali
# 148                             Samoa               Apia
# 150                      S�����������              S����
# 152                           Senegal              Dakar
# 155                      Sierra Leone           Freetown
# 159                   Solomon Islands            Honiara
# 160                           Somalia          Mogadishu
# 163                       South Sudan               Juba
# 166                             Sudan           Khartoum
# 171                        Tajikistan           Dushanbe
# 172                          Tanzania             Dodoma
# 174                        East Timor               Dili
# 175                              Togo               Lom�
# 176                             Tonga           Nuku����
# 182                            Uganda            Kampala
# 189                           Vanuatu          Port Vila
# 192                             Yemen              Sanaa
# 193                            Zambia             Lusaka
# 194                          Zimbabwe             Harare

# %% [markdown]
# 4. Encuentra el valor de "Gasoline Price" para el país cuya abreviatura es "AL" utilizando loc.

# %%
df_world.loc[(df_world["Abbreviation"] == 'AL'), ('Country', 'Gasoline Price')]
# Out:
#    Country Gasoline Price
# 1  Albania         $1.36

# %%
df_world
# Out:
#      Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0             0  Afghanistan               60           AF
# 1             1      Albania              105           AL
# 2             2      Algeria               18           DZ
# 3             3      Andorra              164           AD
# 4             4       Angola               26           AO
# ..          ...          ...              ...          ...
# 190         190    Venezuela               32           VE
# 191         191      Vietnam              314           VN
# 192         192        Yemen               56           YE
# 193         193       Zambia               25           ZM
# 194         194     Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                  58.10%        652,230       32.49          93.0
# 1                  43.10%         28,748       11.78         355.0
# 2                  17.40%      2,381,741       24.28         213.0
# 3                  40.00%            468        7.20         376.0
# 4                  47.50%      1,246,700       40.73         244.0
# ..                    ...            ...         ...           ...
# 190                24.50%        912,050       17.88          58.0
# 191                39.30%        331,210       16.75          84.0
# 192                44.60%        527,968       30.45         967.0
# 193                32.10%        752,618       36.19         260.0
# 194                41.90%        390,757       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 1               Tirana         4,536    119.05          1.40%           ALL
# 2              Algiers       150,006    151.36          2.00%           DZD
# 3     Andorra la Vella           469       NaN            NaN           EUR
# 4               Luanda        34,693    261.73         17.10%           AOA
# ..                 ...           ...       ...            ...           ...
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 0              4.47             2.10%         $0.70
# 1              1.62            28.10%         $1.36
# 2              3.02             0.80%         $0.28
# 3              1.27            34.00%         $1.51
# 4              5.52            46.30%         $0.97
# ..              ...               ...            ...
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34
#
# [195 rows x 16 columns]

# %% [markdown]
# 5. Selecciona todas las columnas para el país cuya capital es "Tirana" utilizando loc.

# %%
df_world.loc[(df_world["Capital/Major City"] == 'Tirana')]
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 1           1  Albania              105           AL                43.10%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 1         28,748       11.78         355.0             Tirana         4,536
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 1  119.05          1.40%           ALL            1.62            28.10%
#
#   Gasoline Price
# 1         $1.36

# %% [markdown]
# 6. Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI (columna "CPI") sea igual a 128.85.

# %%
# Colocamos el numero entre comillas ya que es un string. 
df_world.loc[(df_world['CPI'] == '128.85')]
# Out:
#     Unnamed: 0     Country Density\n(P/Km2) Abbreviation  \
# 40          40  Costa Rica              100           CR
#
#    Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 40                34.50%         51,100       13.97         506.0
#
#    Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 40      San Jos������         8,023  128.85          2.10%           CRC
#
#     Fertility Rate Forested Area (%) Gasoline Price
# 40            1.75            54.60%         $0.98

# %% [markdown]
# 7. Encuentra la densidad (columna "Density\n(P/Km2)") para el país cuya abreviatura es "AD" utilizando loc.

# %%
df_world.loc[(df_world["Abbreviation"] == "AD"), ("Country","Density\n(P/Km2)")]
# Out:
#    Country Density\n(P/Km2)
# 3  Andorra              164

# %% [markdown]
# 8. Selecciona las columnas "Country" y "Co2-Emissions".

# %%
df_world.loc[:,["Country","Co2-Emissions"]]
# Out:
#          Country Co2-Emissions
# 0    Afghanistan         8,672
# 1        Albania         4,536
# 2        Algeria       150,006
# 3        Andorra           469
# 4         Angola        34,693
# ..           ...           ...
# 190    Venezuela       164,175
# 191      Vietnam       192,668
# 192        Yemen        10,609
# 193       Zambia         5,141
# 194     Zimbabwe        10,983
#
# [195 rows x 2 columns]

# %% [markdown]
# 9. Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI cambió un 2% (columna "CPI Change (%)").

# %%
# Colocamos 2.00% entre comillas ya que es tipo string: 
df_world.loc[(df_world["CPI Change (%)"] == '2.00%')]
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 2           2  Algeria               18           DZ                17.40%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 2      2,381,741       24.28         213.0            Algiers       150,006
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 2  151.36          2.00%           DZD            3.02             0.80%
#
#   Gasoline Price
# 2         $0.28

# %% [markdown]
# 10. Encuentra la tasa de natalidad (columna "Birth Rate") para el país con la abreviatura "AF" utilizando loc.

# %%
df_world.loc[(df_world["Abbreviation"] == "AF"), ("Country","Birth Rate")]
# Out:
#        Country  Birth Rate
# 0  Afghanistan       32.49

# %% [markdown]
# 11. Selecciona todas las columnas de las filas 3 a 5 (excluyendo la fila 5) utilizando iloc.

# %%
# Accedemos por sus posiciones en el índice 
df_world.iloc[3:5]
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 3           3  Andorra              164           AD                40.00%
# 4           4   Angola               26           AO                47.50%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 3            468        7.20         376.0   Andorra la Vella           469
# 4      1,246,700       40.73         244.0             Luanda        34,693
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 3     NaN            NaN           EUR            1.27            34.00%
# 4  261.73         17.10%           AOA            5.52            46.30%
#
#   Gasoline Price
# 3         $1.51
# 4         $0.97

# %% [markdown]
# 12. Selecciona las columnas 1, 3 y 6 para todas las filas utilizando iloc.

# %%
# Seleccionamos columnas segun posiciones y todas las filas con ':'
df_world.iloc[[1,3,6], :]
# Out:
#    Unnamed: 0    Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 1           1    Albania              105           AL                43.10%
# 3           3    Andorra              164           AD                40.00%
# 6           6  Argentina               17           AR                54.30%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 1         28,748       11.78         355.0             Tirana         4,536
# 3            468        7.20         376.0   Andorra la Vella           469
# 6      2,780,400       17.02          54.0       Buenos Aires       201,348
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 1  119.05          1.40%           ALL            1.62            28.10%
# 3     NaN            NaN           EUR            1.27            34.00%
# 6  232.75         53.50%           ARS            2.26             9.80%
#
#   Gasoline Price
# 1         $1.36
# 3         $1.51
# 6         $1.10

# %% [markdown]
# 13. Selecciona todas las filas de las columnas 0 a 4 (excluyendo la columna 4) utilizando iloc.

# %%
# seleccinoamos filas de las columnas rango 0:4
df_world.iloc[:, 0:4]
# Out:
#      Unnamed: 0      Country Density\n(P/Km2) Abbreviation
# 0             0  Afghanistan               60           AF
# 1             1      Albania              105           AL
# 2             2      Algeria               18           DZ
# 3             3      Andorra              164           AD
# 4             4       Angola               26           AO
# ..          ...          ...              ...          ...
# 190         190    Venezuela               32           VE
# 191         191      Vietnam              314           VN
# 192         192        Yemen               56           YE
# 193         193       Zambia               25           ZM
# 194         194     Zimbabwe               38           ZW
#
# [195 rows x 4 columns]

# %% [markdown]
# 14. Encuentra el valor en la fila 2 y columna 7 utilizando iloc.

# %%
# Accedemos a la fila 2 y columna 7(calling code):
df_world.iloc[2, 7]
# Out:
# 213.0

# %% [markdown]
# 15. Selecciona todas las filas para las columnas 0, 2, y 5 utilizando iloc.

# %%
df_world.iloc[:, [0,2,5]]
# Out:
#      Unnamed: 0 Density\n(P/Km2) Land Area(Km2)
# 0             0               60        652,230
# 1             1              105         28,748
# 2             2               18      2,381,741
# 3             3              164            468
# 4             4               26      1,246,700
# ..          ...              ...            ...
# 190         190               32        912,050
# 191         191              314        331,210
# 192         192               56        527,968
# 193         193               25        752,618
# 194         194               38        390,757
#
# [195 rows x 3 columns]

# %% [markdown]
# 16. Selecciona las filas 0, 2 y 4 para todas las columnas utilizando iloc.

# %%
df_world.iloc[[0,2,4], :]
# Out:
#    Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0           0  Afghanistan               60           AF
# 2           2      Algeria               18           DZ
# 4           4       Angola               26           AO
#
#   Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                58.10%        652,230       32.49          93.0
# 2                17.40%      2,381,741       24.28         213.0
# 4                47.50%      1,246,700       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 2            Algiers       150,006  151.36          2.00%           DZD
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 2            3.02             0.80%         $0.28
# 4            5.52            46.30%         $0.97

# %% [markdown]
# 17. Encuentra el valor en la última fila y la última columna utilizando iloc.

# %%
# Accedemos a la última fila y última columna 
df_world.iloc[-1,-1]
# Out:
# '$1.34 '

# %% [markdown]
# 18. Selecciona las filas 1 a 3 (inclusive) para todas las columnas utilizando iloc.

# %%
df_world.iloc[1:4, :]
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 1           1  Albania              105           AL                43.10%
# 2           2  Algeria               18           DZ                17.40%
# 3           3  Andorra              164           AD                40.00%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 1         28,748       11.78         355.0             Tirana         4,536
# 2      2,381,741       24.28         213.0            Algiers       150,006
# 3            468        7.20         376.0   Andorra la Vella           469
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 1  119.05          1.40%           ALL            1.62            28.10%
# 2  151.36          2.00%           DZD            3.02             0.80%
# 3     NaN            NaN           EUR            1.27            34.00%
#
#   Gasoline Price
# 1         $1.36
# 2         $0.28
# 3         $1.51

# %% [markdown]
# 19. Selecciona todas las filas para las columnas 1, 4 y 6 utilizando iloc.

# %%
df_world.iloc[:, [1,4,6]]
# Out:
#          Country Agricultural Land( %)  Birth Rate
# 0    Afghanistan                58.10%       32.49
# 1        Albania                43.10%       11.78
# 2        Algeria                17.40%       24.28
# 3        Andorra                40.00%        7.20
# 4         Angola                47.50%       40.73
# ..           ...                   ...         ...
# 190    Venezuela                24.50%       17.88
# 191      Vietnam                39.30%       16.75
# 192        Yemen                44.60%       30.45
# 193       Zambia                32.10%       36.19
# 194     Zimbabwe                41.90%       30.68
#
# [195 rows x 3 columns]

# %% [markdown]
# 20. Encuentra el valor en la fila 4 y columna 2 utilizando iloc.

# %%
df_world.head(5)
# Out:
#    Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0           0  Afghanistan               60           AF
# 1           1      Albania              105           AL
# 2           2      Algeria               18           DZ
# 3           3      Andorra              164           AD
# 4           4       Angola               26           AO
#
#   Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                58.10%        652,230       32.49          93.0
# 1                43.10%         28,748       11.78         355.0
# 2                17.40%      2,381,741       24.28         213.0
# 3                40.00%            468        7.20         376.0
# 4                47.50%      1,246,700       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %%
# Comprobamos con el dataframe anterior que el resultado corresponde con la columna Density de la fila 4. 
df_world.iloc[4,2]
# Out:
# '26'
